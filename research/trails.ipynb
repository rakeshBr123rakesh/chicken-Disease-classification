# %%
d={"key":"value","key1":"value1"}

# %%
d["key"]
# Out:
# 'value'

# %%
d.keys
# Out:
# <function dict.keys()>

# %%
from box import ConfigBox

# %%
d2=ConfigBox({"key":"value","key1":"value1"})

# %%
d2
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1'})

# %%
d2.key
# Out:
# 'value'

# %%
def get_product(x:int,y:int)->int:
    return x*y

# %%
get_product(x=2,y=3)
# Out:
# 6

# %%
get_product(x=2,y="4")
# Out:
# '44'

# %%
from ensure import ensure_annotations
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from ensure import ensure_annotations
#
# File c:\Users\Rakesh\Desktop\career\chicken-disease-classification\chicken-Disease-classification\venv\Lib\site-packages\ensure\__init__.py:4
#       1 from __future__ import absolute_import, division, print_function, unicode_literals
#       3 from ._types import NumericString, NumericByteString, IntegerString, IntegerByteString
# ----> 4 from .main import EnsureError, Ensure, Check, ensure, check, ensure_raises, ensure_raises_regex, ensure_annotations
#
# File c:\Users\Rakesh\Desktop\career\chicken-disease-classification\chicken-Disease-classification\venv\Lib\site-packages\ensure\main.py:922
#     919 check = Check()
#     921 ensure_raises = unittest_case.assertRaises
# --> 922 ensure_raises_regex = unittest_case.assertRaisesRegexp
#
# AttributeError: 'TestCase' object has no attribute 'assertRaisesRegexp'
